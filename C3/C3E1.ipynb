# %%
import pandas as pd
import seaborn as sns
import sklearn as sk

# %%
df = pd.read_csv("data_E1 (1).csv")

# %%
display(df)
# Out:
#      Unnamed: 0 species     island  culmen_length_mm  culmen_depth_mm  \
# 0             0  Adelie  Torgersen              39.1             18.7
# 1             1  Adelie  Torgersen              39.5             17.4
# 2             2  Adelie  Torgersen              40.3             18.0
# 3             3  Adelie  Torgersen               NaN              NaN
# 4             4  Adelie  Torgersen              36.7             19.3
# ..          ...     ...        ...               ...              ...
# 339         339  Gentoo     Biscoe               NaN              NaN
# 340         340  Gentoo     Biscoe              46.8             14.3
# 341         341  Gentoo     Biscoe              50.4             15.7
# 342         342  Gentoo     Biscoe              45.2             14.8
# 343         343  Gentoo     Biscoe              49.9             16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# ...

# %%
df["culmen_length_mm"].fillna(df["culmen_length_mm"].mean(),inplace =True)
df["culmen_depth_mm"].fillna(df["culmen_depth_mm"].mean(),inplace =True)
df["flipper_length_mm"].fillna(df["flipper_length_mm"].mean(),inplace =True)
df["body_mass_g"].fillna(df["body_mass_g"].mean(),inplace =True)

# %%
display(df)
# Out:
#      Unnamed: 0 species     island  culmen_length_mm  culmen_depth_mm  \
# 0             0  Adelie  Torgersen          39.10000         18.70000
# 1             1  Adelie  Torgersen          39.50000         17.40000
# 2             2  Adelie  Torgersen          40.30000         18.00000
# 3             3  Adelie  Torgersen          43.92193         17.15117
# 4             4  Adelie  Torgersen          36.70000         19.30000
# ..          ...     ...        ...               ...              ...
# 339         339  Gentoo     Biscoe          43.92193         17.15117
# 340         340  Gentoo     Biscoe          46.80000         14.30000
# 341         341  Gentoo     Biscoe          50.40000         15.70000
# 342         342  Gentoo     Biscoe          45.20000         14.80000
# 343         343  Gentoo     Biscoe          49.90000         16.10000
#
#      flipper_length_mm  body_mass_g     sex
# 0           181.000000  3750.000000    MALE
# ...

# %%
def conteo_nulo(x):
  return sum(x.isnull())
df.apply(conteo_nulo,axis=0)
# Out:
# Unnamed: 0            0
# species               0
# island                0
# culmen_length_mm      0
# culmen_depth_mm       0
# flipper_length_mm     0
# body_mass_g           0
# sex                  10
# dtype: int64

# %%
df.dropna(subset=["sex"],inplace=True)

# %%
display(df)
# Out:
#      Unnamed: 0 species     island  culmen_length_mm  culmen_depth_mm  \
# 0             0  Adelie  Torgersen              39.1             18.7
# 1             1  Adelie  Torgersen              39.5             17.4
# 2             2  Adelie  Torgersen              40.3             18.0
# 4             4  Adelie  Torgersen              36.7             19.3
# 5             5  Adelie  Torgersen              39.3             20.6
# ..          ...     ...        ...               ...              ...
# 338         338  Gentoo     Biscoe              47.2             13.7
# 340         340  Gentoo     Biscoe              46.8             14.3
# 341         341  Gentoo     Biscoe              50.4             15.7
# 342         342  Gentoo     Biscoe              45.2             14.8
# 343         343  Gentoo     Biscoe              49.9             16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# ...

# %%
df.apply(conteo_nulo,axis=0)
# Out:
# Unnamed: 0           0
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# Mision 2:

# %%
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
from sklearn.preprocessing import LabelEncoder
df1 = df.copy()
df_sex = ['sex',"species","island"]
label_encoder = LabelEncoder()
for i in df_sex:
    df1[i] = label_encoder.fit_transform(df1[i])
df1.dtypes
# Out:
# Unnamed: 0             int64
# species                int64
# island                 int64
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                    int64
# dtype: object

# %%
training_set, test_set = train_test_split(df1.copy(), test_size = 0.3)

print(f'Tamaño set entrenamiento: {len(training_set)}')
print(f'Tamaño set test: {len(test_set)}')
# Out:
# Tamaño set entrenamiento: 233
# Tamaño set test: 101

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = ["species","island","culmen_length_mm","culmen_depth_mm","flipper_length_mm","body_mass_g","sex"]

training_set[features] = scaler.fit_transform(training_set[features])
test_set[features] = scaler.transform(test_set[features])

display(training_set)
# Out:
#      Unnamed: 0   species    island  culmen_length_mm  culmen_depth_mm  \
# 153         153  0.169155  0.432749          1.220785         1.133111
# 258         258  1.295245 -0.948491          0.088974        -1.826584
# 219         219  0.169155  0.432749          1.258512         0.731796
# 340         340  1.295245 -0.948491          0.617153        -1.475434
# 110         110 -0.956935 -0.948491         -1.023973        -0.371819
# ..          ...       ...       ...               ...              ...
# 281         281  1.295245 -0.948491          0.503971        -1.174448
# 236         236  1.295245 -0.948491         -0.288296        -1.876748
# 218         218  0.169155  0.432749          1.371693         0.882289
# 136         136 -0.956935  0.432749         -1.495561         0.129824
# 238         238  1.295245 -0.948491          0.503971        -1.375105
#
#      flipper_length_mm  body_mass_g       sex
# 153          -0.309929    -0.343250  0.987491
# ...
